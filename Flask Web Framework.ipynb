# %% [markdown]
# ### Web Framework

# %%
A Web Framework is a software framework used to build web applications and REST APIs efficiently by providing 
reusable components and handling common web development tasks

Flask
FastAPI
DJango

# %% [markdown]
# ### Flask Web Framework

# %%
Flask is a lightweight Python web framework used to build web applications, APIs, and 
backend services quickly and efficiently

It is called a micro-framework because it provides only the essentials:
    - URL routing
    - Request handling
    - Response generation
    - Template rendering

Flask is built on top of two important Python libraries:

Werkzeug > Handles HTTP requests/responses and WSGI utilities
Jinja2 > Template engine for rendering HTML

Flask is widely used because it is:
    - Simple and beginner-friendly
    - Flexible
    - Lightweight
    - Easy to scale
    - Great for REST APIs
    - Easy to learn compared to larger frameworks

# %% [markdown]
# #### install flask

# %%
pip install flask

# %% [markdown]
# #### Running Flask App

# %%
python main.py
python app.py

Running on http://127.0.0.1:5000/

# %% [markdown]
# #### Templates in Flask

# %%
Flask uses the Jinja2 template engine.
    - Templates are stored in a templates/ folder.

project/
│
├── main.py
├── templates/
│   └── index.html

# %% [markdown]
# ### HTTP Methods in Flask / Web Development

# %%
HTTP methods define what action the client wants to perform on a resource.

HTTPS >>  HyperText Transfer Protocol Secure
HTTP  >>  HyperText Transfer Protocol

Methods:
GET	>> Retrieve data
POST >> Create new data
DELETE >> Delete data
PUT >>	Update entire data
PATCH >> Update partial data

# %% [markdown]
# ### REST API

# %%
REST API stands for Representational State Transfer Application Programming Interface.

# %% [markdown]
# ### Request Object in Flask

# %%
The request object in Flask is used to access data sent by the client to the server

request.form >>	Form data sent from HTML forms
request.get_json() or request.json >>	JSON data sent in request body
request.files >> Uploaded files
request.method >>	HTTP method (GET, POST, PUT, DELETE)
request.args >>	Query parameters from URL

# %%
pip freeze
# Out:
# anyio==4.12.1
# argon2-cffi==25.1.0
# argon2-cffi-bindings==25.1.0
# arrow==1.4.0
# asttokens==3.0.1
# async-lru==2.2.0
# attrs==25.4.0
# babel==2.18.0
# beautifulsoup4==4.14.3
# bleach==6.3.0
# blinker==1.9.0
# certifi==2026.2.25
# cffi==2.0.0
# charset-normalizer==3.4.4
# click==8.4.2
# colorama==0.4.6
# comm==0.2.3
# contourpy==1.3.3
# cycler==0.12.1
# debugpy==1.8.20
# decorator==5.2.1
# defusedxml==0.7.1
# dnspython==2.8.0
# executing==2.2.1
# fastjsonschema==2.21.2
# filelock==3.25.2
# Flask==3.1.3
# Flask-JWT-Extended==4.7.4
# fonttools==4.62.1
# fqdn==1.5.1
# fsspec==2026.2.0
# h11==0.16.0
# httpcore==1.0.9
# httpx==0.28.1
# idna==3.11
# imbalanced-learn==0.14.1
# imblearn==0.0
# ipykernel==7.2.0
# ipython==9.10.0
# ipython_pygments_lexers==1.1.1
# ipywidgets==8.1.8
# isoduration==20.11.0
# itsdangerous==2.2.0
# jedi==0.19.2
# Jinja2==3.1.6
# joblib==1.5.3
# json5==0.13.0
# jsonpointer==3.0.0
# jsonschema==4.26.0
# jsonschema-specifications==2025.9.1
# jupyter==1.1.1
# ...
